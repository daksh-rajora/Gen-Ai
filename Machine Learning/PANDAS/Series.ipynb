# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Series is a cloumn of data in a Table like in Excel or Google Sheets with labels called as indexes attached to each value.

# %%
pd.Series(data=[40,50,60], index=['Bread','Milk','Butter'], name='Price of Grocery Items')
# Out:
# Bread     40
# Milk      50
# Butter    60
# Name: Price of Grocery Items, dtype: int64

# %% [markdown]
# ### Series is a 1D Array that can hold any type of data like integers, float, strings(object), boolean,mixed data type.

# %% [markdown]
# ### Data type ---> Integers ---> Data in a Series(Column)--->Quantity of items in the Stock
# ### Data type ---> Float ---> Data in Series (Column) ---> Price or Product Ratings
# ### Data type ---> Strings ---> Column ---> Product Name
# ### Data type ---> Boolean ---> Column ---> Is item in stocl?
# ### Data type ---> Dates / Times ---> Column ---> Expiry Dates or sales Dates
# ### Mixed Types ---> Milk,40,True

# %% [markdown]
# ## Creating a series in multiple ways
# ### 1. List
# ### 2. Numpy Array
# ### 3. Dictionary
# ### 4. Custom Index
# ### 5. Scalar Value

# %%
# Series from list

country=['India','China','USA','Pakistan']

pd.Series(country)
# Out:
# 0       India
# 1       China
# 2         USA
# 3    Pakistan
# dtype: object

# %%
batsman_runs=[48,64,72,98,114,183]
pd.Series(batsman_runs,dtype='int32')
# Out:
# 0     48
# 1     64
# 2     72
# 3     98
# 4    114
# 5    183
# dtype: int32

# %%
subject_names=['Math','Physics','Chemistry','Biology','English']
subject_marks=[34,54,23,45,64]

pd.Series(data=subject_marks,index=subject_names,name='Marks Scored' )
# Out:
# Math         34
# Physics      54
# Chemistry    23
# Biology      45
# English      64
# Name: Marks Scored, dtype: int64

# %%
## creating a series using numpy arrays
values=np.arange(10,21)
pd.Series(values)
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# dtype: int64

# %%
## Dictionaries to series

## Dictionaries is another data structure that stores the data in a key value pair and just because it 
# stores the data in akey value pair we dont have to explicitly mention the index

data_items={'Maths':78,'English':92,'Physics':76}
pd.Series(data_items)
# Out:
# Maths      78
# English    92
# Physics    76
# dtype: int64

# %%
# custom index to series
values=[1,2,3,4,5,6]
pd.Series(data=values, index=['a','b','c','d','e','f'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %%
# scalar value inside an series
pd.Series(4,
index=['a','b','c','d','e','f'])
# Out:
# a    4
# b    4
# c    4
# d    4
# e    4
# f    4
# dtype: int64

# %%
# read_csv()--> This function reads the content from the csv file in pandas so that we can perform 
# the operations on the data or we can perform effective analysis

Data=pd.read_csv("youtube_2025_dataset_202504061614.csv")

# %%
Data
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
df = pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
# DataFrame--->. Combination of Multiple Series(Column)
# squeeze---> squeeze parameter makes sure that the data is in series format
# index_col---> df = pd.read_csv('youtube_2025_dataset_202504061614.csv',index_col='Youtuber Name').squeeze('columns)

# %%
## Attribute in Series 
# 1. .values --> representing only the values of the given series
# 2. .index-->  returns only the index values from the given column
# 3. .dtype--> Dtype provides the idea about the data type of the values that you are storing 
# 4. .size---> this attribute provides the idea about the total number of rows inside the dataset
# 5. .shape --> this attribute provides the idea about the row column information
# 6. .ndim--> provides the idea about the dimension of the given dataset
# 7. .name --> this attribute provides the idea about the name of the series
# 8. .is_unique ---> this attribute helps us to know whether the values inside the series are unique or not

# %% [markdown]
# ## Series Methods
# #### 1. head()---> Provides the Top Preview of Data as the Top 5 Rows of the dataframe or series. It  is quite helpful with providing the preview of the dataset and if we want to preview top 10 rows then we can pass 10 as a argument or for top 7 rows we can pass 7 as an argument.
#
# #### 2. tail()--> provides the bottom preview of Data as the Bottom 5 Rows.
#
# #### for eg ---> dataset ---> salary column ---> top 5 rows ---> salary ---> 7 LPA ---> top 10 ---> top 15.... tail() ---> bottom 5 rows ---> salary ---> 4 LPA,9 LPA
#
# #### 3. sample() ---> sample() provides any custom row from the dataset for us to preview it
#
# #### 4. value_counts()---> it provides the idea about the count of the values (categorical values), if i am having a column where the categorical value count i want to calculate then i can go with value_counts()
#
# #### 5. sort_values() --> this method sorts the value in an ascending manner. it can be useful for us fot the numerical columns. you can sort the value in descending manner as well
#
# #### 6. sort_index() ---> this method sorts the index of the dataset.

# %%
df.values
# Out:
# array([['Smith-Ross Labs', 'Eric Patel', 68, ..., '3D', 130655.44,
#         6.199999999999999],
#        ['Sandoval PLC Hub', 'Cynthia Harrington', 128, ..., '3D',
#         138624.73, 21.4],
#        ['Jones, Moore and Ho Network', 'Amanda Walker', 282, ..., '1D',
#         97442.53, 13.499999999999998],
#        ...,
#        ['Obrien-Roberts Studios', 'Lisa Burke', 179, ..., '1D', 36592.98,
#         33.2],
#        ['King Ltd Hub', 'Steve Diaz', 182, ..., '4D', 109955.22, 6.6],
#        ['Henry Ltd Studios', 'Austin Tate', 92, ..., '3D', 107272.81,
#         21.2]], shape=(5000, 14), dtype=object)

# %%
df.size
# Out:
# 70000

# %%
youtube =pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
avg = youtube['Avg Video Length (min)']

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
type(avg)
# Out:
# pandas.core.series.Series

# %%
avg.value_counts()
# Out:
# Avg Video Length (min)
# 24.1    276
# 23.8    264
# 23.9    256
# 24.2    253
# 24.0    251
#        ...
# 20.6      1
# 28.0      1
# 21.0      1
# 20.7      1
# 21.1      1
# Name: count, Length: 78, dtype: int64

# %%
avg.sort_values()
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
# parameter--> ascending = false (sorting---> descending)

# %%
avg.sort_values(ascending=False)
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Method chaining --> we will ues multiple methods together to get the required required value in a way the first method's output will be second method input then 2nd method output will be 3rd method input

# %%
avg.sort_values(ascending=False).head(1)
# Out:
# 361    28.9
# Name: Avg Video Length (min), dtype: float64

# %%
avg.sort_values(ascending=False).head(1).values[0]
# Out:
# np.float64(28.9)

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
## In order to make a change in our data permanent --> inplace

avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.sort_values()
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
average_data=avg.copy()

# %%
average_data
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
average_data.sort_values(inplace=True)

# %%
average_data
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
print(youtube.head())
# Out:
#                   Channel Name       Youtuber Name  Total Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best Video  Avg Video Length (min)  \
# 0           VR Challenge: Review 2023                    24.8
# 1  Nanotech Simulation: Analysis 2024                    22.9
# 2  Metaverse Interface: Analysis 2024                    24.0
# 3            VR Protocol: Review 2023                    24.6
# 4    Nanotech Simulation: Review 2024                    24.6
#
#    Total Subscribers  Members Count  AI Generated Content (%)  \
# 0            8264152         303319                         9
# 1            8768222         384629                        62
# ...

# %%
subs=youtube['subscribers']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\daksh\anaconda10\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subscribers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 subs=youtube['subscribers']
#
# ...

# %%
subs
# Out:
# 0      16600000
# 1       4860000
# 2       4010000
# 3       2990000
# 4       2080000
#          ...
# 125       11400
# 126       11200
# 127       11000
# 128       10900
# 129       10800
# Name: subscribers, Length: 130, dtype: int64

# %% [markdown]
# ## Mathematical Functions in Pandas
# ### 1. sum() --> sum of all values present in the series
# ### 2. product() ---> product of all values in the series
# ### 3. mean() ---> Mean provides us with the average value of the data column.
# ### for eg ---> Company data---> salary ---> average value for that column salary = 7,6,8,9,11 mean = (6+6+8+9+11)/5 ---> 8 LPA
#
# ### median()---> Median also provides the idea about the average of the data. for coming up with median, we need to SORT the values in Ascending manner and then the middle value after sorting the data --> median; data ---> salary---> 1 crore, 10 crore (Outlier) --> avg --> 7+8+6+9
#
# ### mode() --> mode provides us with the idea that which value is getting repeated maximum number of times.
#
# ### std()--> if i need to get the idea that how the values inside the series are distributed from the average or mean value then we can come up with the standard deviation
# #### salary ---> 7,8,6,6.5,7.5 ---> low standard deviation
# #### salary --> 7,15,4,20,28,17 ---> high standard deviation
#
# ### variance --> variance also provides the insight about the distribution of the data from the mean value and variance is the square of the standard deviation.
#
# #### standard_deviation = |mean - v_1| + |mean - v_2| ..../total count of values
# #### variance = std**2
#
# ### min() ---> minimum value in the series
# ### max() --> maximum value in the series
# ### describe() ---> describe function provides the idea about the summary of the important mathematical calculaations for the data.
#
# #### min---> minimum value
# #### max--> maximum value
# #### mean--> average value
# #### std --> standard deviation
# #### 25%---> 255 of the values out of my all values are less than this specific value
# #### 50% ---> 50% of the values out of all my values are less than this value
# #### 75% ---> 75% of the values out of all my values are less than this specific value
#
# #### count--> total number of rouws in the column
#
# ##### JEE mains ---> 25% ---> my score in jee maiins was greater than 25% of the total applicants who applied in jee

# %%
subs.sum()
# Out:
# np.int64(66604700)

# %%
subs.product()
# Out:
# np.int64(0)

# %%
subs.sort_values()
# Out:
# 129       10800
# 128       10900
# 127       11000
# 126       11200
# 125       11400
#          ...
# 4       2080000
# 3       2990000
# 2       4010000
# 1       4860000
# 0      16600000
# Name: subscribers, Length: 130, dtype: int64

# %%
subs.mean()
# Out:
# np.float64(512343.8461538461)

# %%
subs.median()
# Out:
# 120000.0

# %%
subs.mode()
# Out:
# 0    120000
# Name: subscribers, dtype: int64

# %%
avg=youtube['total_views']

# %%
avg
# Out:
# 0      9092244390
# 1       257598451
# 2       870967915
# 3       178609297
# 4        82120292
#           ...
# 125        302138
# 126       6878757
# 127        130381
# 128        587499
# 129        839331
# Name: total_views, Length: 130, dtype: int64

# %%
avg.std()
# Out:
# 806890880.2699572

# %%
avg.var()
# Out:
# 6.510728926628264e+17

# %%
avg.min()
# Out:
# 26785

# %%
avg.max()
# Out:
# 9092244390

# %%
avg.describe()
# Out:
# count    1.300000e+02
# mean     1.237155e+08
# std      8.068909e+08
# min      2.678500e+04
# 25%      2.681172e+06
# 50%      1.059262e+07
# 75%      3.823083e+07
# max      9.092244e+09
# Name: total_views, dtype: float64

# %% [markdown]
# ## Indexing in Series (To have the access over the  certain value or values)
#
# ### 1.Positive Indexing (Just like list) --> start from 0 to forward direction
# ### 2. No negative indexing
# ### 3. Slicing --> In the sries we can get the certain values over a given specific range and we can do it using [initial_val:final_val + 1]
# ### 3. Fancy Indexing ---> If i want the specific values from the series then we can go with fancy indexing
# ### 5. Indexing with Labels ---> A series which is consisting of labels as the index or custom index, then for this data we can retrieve the info using that custom index or label

# %%
avg
# Out:
# 0      9092244390
# 1       257598451
# 2       870967915
# 3       178609297
# 4        82120292
#           ...
# 125        302138
# 126       6878757
# 127        130381
# 128        587499
# 129        839331
# Name: total_views, Length: 130, dtype: int64

# %%
avg[0]
# Out:
# np.int64(9092244390)

# %%
avg[5]
# Out:
# np.int64(628661984)

# %%
avg(-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 avg(-1)
#
# TypeError: 'Series' object is not callable

# %%
avg[7:18]
# Out:
# 7      293634526
# 8      105351847
# 9     1247156348
# 10     110240344
# 11     250689795
# 12      56374730
# 13     104029236
# 14      44883407
# 15     309863327
# 16      35150876
# 17     117271612
# Name: total_views, dtype: int64

# %%
## If i eant the values skipped as a certain value
avg[2:21:2]
# Out:
# 2     870967915
# 4      82120292
# 6     131666208
# 8     105351847
# 10    110240344
# 12     56374730
# 14     44883407
# 16     35150876
# 18    197934117
# 20    143994316
# Name: total_views, dtype: int64

# %%
## Reverse values in a series
avg[::-1]
# Out:
# 129        839331
# 128        587499
# 127        130381
# 126       6878757
# 125        302138
#           ...
# 4        82120292
# 3       178609297
# 2       870967915
# 1       257598451
# 0      9092244390
# Name: total_views, Length: 130, dtype: int64

# %%
avg[[2,3,4,5,6,3]]
# Out:
# 2    870967915
# 3    178609297
# 4     82120292
# 5    628661984
# 6    131666208
# 3    178609297
# Name: total_views, dtype: int64

# %%
df
# Out:
#                    channel_id                     channel_name  \
# 0    UCXuqSBlHAE6Xw-yeJA0Tunw                  Linus Tech Tips
# 1    UCWv7vMbMWH4-V0ZXdmDpPBA            Programming with Mosh
# 2    UChIZGfcnjHI0DG4nweWEduw                       TechSource
# 3    UC4SVo0Ue36XCfOyb5Lh1viQ                         Bro Code
# 4    UCVeW9qkBjo3zosnqUbG7CFw                     John Hammond
# ..                        ...                              ...
# 125  UCBKM3HATRILZyG9jGNJKGXQ       Software Engineering Daily
# 126  UCvckuc-3Sos1aUtSqCV_0xw          Georgia Web Development
# 127  UC4lM4hz_v5ixNjK54UwPEVw  Machine Learning and AI Academy
# 128  UCTnOFmMwZIi7jJYS_nAfeyQ               The Helpful Hacker
# 129  UCHd1qamEkVSlTWkEqIqJbEQ          Visual Computer Science
#
#                                            description  subscribers  \
# 0    Linus Tech Tips is a passionate team of "profe...     16600000
# 1    Hi! I'm Mosh 👋, a software engineer with over ...      4860000
# ...

# %%
youtube
# Out:
#                    channel_id                     channel_name  \
# 0    UCXuqSBlHAE6Xw-yeJA0Tunw                  Linus Tech Tips
# 1    UCWv7vMbMWH4-V0ZXdmDpPBA            Programming with Mosh
# 2    UChIZGfcnjHI0DG4nweWEduw                       TechSource
# 3    UC4SVo0Ue36XCfOyb5Lh1viQ                         Bro Code
# 4    UCVeW9qkBjo3zosnqUbG7CFw                     John Hammond
# ..                        ...                              ...
# 125  UCBKM3HATRILZyG9jGNJKGXQ       Software Engineering Daily
# 126  UCvckuc-3Sos1aUtSqCV_0xw          Georgia Web Development
# 127  UC4lM4hz_v5ixNjK54UwPEVw  Machine Learning and AI Academy
# 128  UCTnOFmMwZIi7jJYS_nAfeyQ               The Helpful Hacker
# 129  UCHd1qamEkVSlTWkEqIqJbEQ          Visual Computer Science
#
#                                            description  subscribers  \
# 0    Linus Tech Tips is a passionate team of "profe...     16600000
# 1    Hi! I'm Mosh 👋, a software engineer with over ...      4860000
# ...

# %% [markdown]
# ## Editing Series(Bring the changes into the values stores inside the series)
#
# #### 1. Using indexing ---> df[0]=65 ---> changing the original value at index 0 to 65

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\daksh\anaconda10\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Linus Tech Tips'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df['Linus Tech Tips']
#
# ...

# %% [markdown]
# ## Series with python functionalities
#
# ### len--->It provides the idea with total number of elements present in the series
# ### type--> It provides the idea about the datatype of the series
# ### dir---> It provides with the idea about all of the methods and attributes associated with the series
# ### sorted---> It sorts the values in ascending manner
#
# ### max ---> It calculates the Max value in the Series
# ### min ---> It calculates the min value in the series

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
sorted(avg)
# Out:
# [19.1,
#  19.3,
#  19.9,
#  20.6,
#  20.7,
#  20.9,
#  20.9,
#  20.9,
#  21.0,
#  21.1,
#  21.2,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.8,
#  21.8,
#  21.8,
#  21.8,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
# ...

# %%
## Package Function ---> object.function()
## Built in Function ---> function(object)

# %%
max(avg)
# Out:
# 28.9

# %%
min(avg)
# Out:
# 19.1

# %% [markdown]
# ## Type conversion in series (just like python)
#
# #### I can convert the data type of the given series into another data type.
#
# #### Series --->into List ---> list(Series)
# #### Series ---> Dictionary ---> dict(Series)

# %%
list_avg=list(avg)

# %%
type(list_avg)
# Out:
# list

# %%
dict(avg)
# Out:
# {0: np.float64(24.8),
#  1: np.float64(22.9),
#  2: np.float64(24.0),
#  3: np.float64(24.6),
#  4: np.float64(24.6),
#  5: np.float64(24.2),
#  6: np.float64(23.2),
#  7: np.float64(25.6),
#  8: np.float64(23.1),
#  9: np.float64(24.2),
#  10: np.float64(22.9),
#  11: np.float64(25.4),
#  12: np.float64(26.9),
#  13: np.float64(23.4),
#  14: np.float64(24.1),
#  15: np.float64(24.9),
#  16: np.float64(24.7),
#  17: np.float64(24.8),
#  18: np.float64(23.6),
#  19: np.float64(24.1),
#  20: np.float64(24.8),
#  21: np.float64(24.2),
#  22: np.float64(23.2),
#  23: np.float64(23.4),
#  24: np.float64(24.9),
#  25: np.float64(24.2),
#  26: np.float64(23.3),
#  27: np.float64(23.6),
#  28: np.float64(25.5),
#  29: np.float64(25.2),
#  30: np.float64(24.6),
#  31: np.float64(24.9),
#  32: np.float64(23.7),
#  33: np.float64(23.2),
#  34: np.float64(24.1),
#  35: np.float64(24.0),
#  36: np.float64(24.3),
#  37: np.float64(23.8),
#  38: np.float64(23.6),
#  39: np.float64(24.9),
# ...

# %%
## Membership Operators 
# Membership operator ---> in ---> It checks that whetehr if the value is in the series or not.
# It checks for the element in the index or label of the seies
# We can go with df.values to check that whether if a member is of a series or not.

# %% [markdown]
# ## Looping in series--> for loop for iterating over the items of the series and for the index iterating we can go with series_name.index

# %%
for i in avg:
    print(i)
# Out:
# 24.8
# 22.9
# 24.0
# 24.6
# 24.6
# 24.2
# 23.2
# 25.6
# 23.1
# 24.2
# 22.9
# 25.4
# 26.9
# 23.4
# 24.1
# 24.9
# 24.7
# 24.8
# 23.6
# 24.1
# 24.8
# 24.2
# 23.2
# 23.4
# 24.9
# 24.2
# 23.3
# 23.6
# 25.5
# 25.2
# 24.6
# 24.9
# 23.7
# 23.2
# 24.1
# 24.0
# 24.3
# 23.8
# 23.6
# 24.9
# 24.0
# 23.4
# 23.3
# 23.9
# 23.8
# 24.5
# 22.9
# 23.1
# 23.4
# 23.9
# 25.6
# 23.3
# 24.6
# 23.9
# 23.1
# 24.9
# 23.0
# 24.1
# 24.0
# 23.4
# 24.9
# 25.9
# 24.7
# 23.5
# 24.0
# 25.8
# 23.7
# 23.9
# 23.8
# 24.0
# 24.0
# 24.1
# 25.1
# 24.3
# 23.9
# 23.5
# 24.4
# 22.9
# 23.1
# 25.1
# 24.8
# 23.7
# 24.1
# 24.4
# 23.9
# 22.1
# 23.7
# 24.5
# 24.2
# 23.8
# 24.2
# 22.8
# 24.9
# 24.4
# 27.0
# 23.2
# 24.5
# 26.1
# 23.4
# 23.4
# 24.1
# 22.3
# 24.1
# 24.3
# 24.1
# 24.8
# 23.8
# 23.7
# 24.2
# 24.4
# 23.7
# 24.2
# 23.1
# 23.4
# 23.9
# 23.9
# 23.6
# 23.4
# 25.6
# 23.3
# 24.1
# 23.4
# 24.7
# 24.8
# 23.9
# 24.4
# 25.1
# 22.9
# 24.6
# 24.4
# 25.0
# 23.7
# 23.6
# 24.7
# 26.0
# 22.8
# 23.6
# 22.8
# 23.2
# 22.9
# 22.4
# 24.3
# ...

# %% [markdown]
# ## Boolean Indexing
# #### In order to perform the important analysis on the column values, where in a specific index value if ot os meeting a condition that we get True over their else we get False when the condition is not meeting for that specific index.
#
# #### Boolean Index ---> True ---> Condition is True
# #### Boolean Index ---> False ---> Condition is not True

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
## Which utubers are having average video length greater than 24 min

avg[avg > 24].size
# Out:
# 2381

# %% [markdown]
# ## Plotting Graphs in Pandas
#
# #### For plotting graphs in Pandas, we require plot() ---> df.plot
# #### kind --> It decides what king of graph u want to plot

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.plot()
# Out:
# <Axes: >

# %%
avg.sort_values(ascending=False).head(15).plot(kind='bar')
# Out:
# <Axes: >

# %%
avg.sort_values(ascending=False).sample(15).plot(kind='bar')
# Out:
# <Axes: >

# %%
avg.sort_values(ascending=False).head(15).plot(kind='pie')
# Out:
# <Axes: ylabel='Avg Video Length (min)'>
