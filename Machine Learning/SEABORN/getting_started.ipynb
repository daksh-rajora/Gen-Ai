# %% [markdown]
# ## Numpy, Pandas, Matplotlib, Plotly, Seaborn ---> All of these Libraries will be required over here

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Relational Plot
#
# #### Relational Plot is being used to figure out the relationship between two or more Numerical Variables and It helps us out to figure out that on bringing the changes in one numerical column, How it affects the other Numerical Column
#
# #### Relational Plot ----> Bivariate Analysis
# #### ---> Numerical - Numerical
# #### ---> One Numerical Column ---> Change ---> How it Affects ---> Other Numerical Column
# #### Line Plot ---> Line Plot is being used for Time Series Analysis (wrt Time how one quantity is going to vary) ---> X axis ---> Time Y axis --> Value that will vary
# #### For ex --> wrt Time How my weight is varying or how sales value is varying with time or how stocl price for a company is varying with Time
# #### Scatterplot --> Scatterplot show how 2 numerical variables vary or are correlated that means if one numerical column will vary then how it will affect the other numerical column
# #### Correlation btw 2 Numerical Column
# #### Study Hours <---> Exam score
# #### Axis Level Functions
# #### Line Plot --> sns.lineplot()
# #### lineplot() --->
# #### data--> dataframe value from where we will be selecting the columns for analysis
# #### x--> 'Column_name' that you want to keep on the X axis and this column name will directly behave as the y label for us
# #### hue --->it can group or seprate the information in the plot with respect to a new column
# #### style ---> style parameter can also add additional insights in the graph by changing the plot stule (lineplot---> line stype will change)
# #### size ---> size of the plot can vary with respect to the column
# #### Scatter Plot --> sns.scatterplot()
# #### Figure Level Function
# #### relplot() ---> it is capable of plotting both scatterplot and lineplot just based on the kind parameter
# #### kind='line'---> lineplot
# #### kind='scatter'---> scatterplot

# %%
# tips

tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## axis level function
sns.lineplot(data=tips,x='day',y='total_bill',hue='smoker',style='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## figure level function

sns.relplot(data=tips,x='day',y='total_bill',kind='line',hue='sex',style='smoker')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(data=tips,x='day',y='total_bill',hue='smoker',style='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.lineplot(data=tips,x='day',y='total_bill',hue='smoker',style='time')
plt.show()

# %%
### people coming for lunch are only coming on Thursday or Friday
### people coming for lunch and are smokers as well paying more bill on Thursday then non smokers and less bill on Friday the Non smokers for lunch
# Non smokers are coming for dinner everyday while smokers for dinner are not coming on Thursday
# Non smokers for dinner are always paying less bill than smoker at dinner

# %% [markdown]
# ### plotly ---> gapreminder dataset --> Is the population and life expactancy of people from a fixed year in multiple countries are continents

# %%
gap=px.data.gapminder()

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gap.shape
# Out:
# (1704, 8)

# %%
gap['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
gap['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gap['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
sns.lineplot(data=gap,x='year',y='lifeExp',hue='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
## gap[(gap['country']=='India') | (gap['country']=='China')]
## isin()--->India,China,Pakistan

data=gap[gap['country'].isin(['India','China','Pakistan'])]

# %%
data
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
sns.relplot(data=data,x='country',y='lifeExp',kind='line')

# %%
data=gap[gap['country'].isin(['India','Brazil','Germany'])]

# %%
data
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
sns.lineplot(data=data,x='country',y='lifeExp')
# Out:
# <Axes: xlabel='country', ylabel='lifeExp'>

# %%
sns.lineplot(data=data,x='year',y='lifeExp',hue='continent',size='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',size='size')
plt.show()

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',size='size',kind='scatter')

# %%
sns.scatterplot(data=gap,x='lifeExp',y='pop',hue='continent')
# Out:
# <Axes: xlabel='lifeExp', ylabel='pop'>

# %% [markdown]
# ## Facet Plot
# #### facet plot can help us divide the plot as per the multiple categories of a categorical column such as let us say, we dont want to use hue and we want to divide the plot or graph as per multiple categories of a categorical column as row wise or column wise then we can go with the facet plot
# #### facet plot can help us separate the info Rowwise or Columnwise
# #### We can use Row or column parameter to mention that if we want to separate the info rowwise or column wise
# #### Facet plot functionality is only possible in the Figure level plot
# #### As figure level plot provides us the control over the whole figure and axis level plot only provides us the control over the axis itself

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x='total_bill',row='sex',y='tip',kind='scatter')

# %%
sns.relplot(data=tips,x='total_bill',col='sex',y='tip',kind='scatter')

# %%
sns.relplot(data=tips,x='total_bill',row='smoker',y='tip',kind='scatter',col='sex')

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.relplot(data=gap,x='lifeExp',col='year',y='pop',kind='scatter',col_wrap=3)

# %% [markdown]
# ### Distribution Plots
#
# #### Distribution Plots provides us the idea about the distribution of data in a given column and typically in an Numerical Column to get to see that how the data is distributed in that column.
# #### It will be used for the Univariate Analysis as we look into the distribution of the given Numerical Column.
# #### We can find out the Outliers from the data as well
# #### We can get the insight if we are having a normal distribution or Skewed and how the shape or Spread or Central Tendency of the Data is.
# #### 1. Histplot --> Histplot is being used to check the distribution of a Numerical column wrt bins as the size of the bin reflects info for equal intervel
#
# #### Axis Level Func ---> histplot()
# #### Syntax--> histplot()
# #### ---> data ---> dataframe where the column is
# #### x---> column_name
# #### bins---> number of bins i want inside my histogram(n)
# #### kde ---> overlays a KDE curve
# #### Figure Level Function
# #### displot() ---> kind='hist'

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.histplot(data=gap,x='lifeExp')
# Out:
# <Axes: xlabel='lifeExp', ylabel='Count'>

# %%
sns.histplot(data=tips,x='total_bill',bins=15,hue='sex',element='step')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Facet plot ---> figure level function ---> displot()
sns.displot(data=tips,x='total_bill',col='sex',kind='hist')

# %% [markdown]
# #### KDE(Kernel Density Estimation) Plot ---> To show the distribution of the data inside a Numerical Column itself but over here instead of getting bins, we can get the smooth curve which comes out as a probability density function representing the Distribution of the Data as with the curve How data is distributed exactly.
#
# #### Axis Level Function ---> sns.kdeplot()
# #### ---> data ---> dataframe
# #### ---> x ---> column whose distribution we want to find
# #### ---> fill ---> To fill under the curve ---> True or False ( By default --> False)

# %%
sns.kdeplot(data=tips,x='total_bill',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data=gap,x='lifeExp')
# Out:
# <Axes: xlabel='lifeExp', ylabel='Density'>

# %% [markdown]
# #### RugPlot ---> It adds the small vertical lines like ticks along the axis that show the individual data points.
# #### More deep the rug plot tick ---> More density we can expect Their
# #### It is usually used in conjuction with other plots like with kde plot as ---> kde Plot + RugPlot
# #### Axis Level Function --->sns.rugplot()

# %%
sns.rugplot(data=gap,x='lifeExp')
# Out:
# <Axes: xlabel='lifeExp'>

# %%
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# ## Bivariate Histogram --> BH creates the histogram in BOTH X and Y axis, as histogram with one Numerical quantity in X direction and One numerical quantity in Y direction and the conjuction of both quantities creates an Rectangle and
# ## More Darker will be the Rectangle <---> More density we can have there
# ## Bivariate Histogram provides us with the Rectangular Grid as the conjuction in both Direction

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Bivariate KDE Plot ---> A Bivariate KDE Plot smoothes the x,y observations with a 2D Gaussian Plane. It will create the Circular Plots and More closer the circular plot <---> More Density we can find there
# ## Circular Figure Closeness (More) <---> Density (More)

# %%
sns.kdeplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Matrics Plot
# #### Matrix Plot shows Relationship between Two Dimensions like a Table using colors to show the strength of pattern of data.
# #### Matrix Plot can be considered similar to those of the Excel sheets where in Excel Sheet cells instead of numbers, we can use the color intensity to understand values.
# #### Heatmap
# #### In Every classification Machine Learning Problem Statement, we use the Heatmap.
# #### Heatmap uses color shades to show the size of Numers in a Matrix 2D table.
# #### Darker or lighter colors indicate higher or lower values.
# #### Super useful when we want to see correlation,  Missing Data, Comparison, density
# #### for ex ---> Sales over the Months in Different Countries
# #### For comming up an Heatmap or an Matrix which we can convert into a Heatmap, we create a Pivot Table and then that pivot table only we can use to create an heatmap
# #### pivot()--->index, columns, values ---> gap.pivot(index='', columns='', values='')
# #### In Matrix Plot, we are not having Figure level function but only Axis Level function
# #### Heatmap --> heatmap()
# #### ---> data ---> matrix that has to be converted into an heatmap
# #### ---> annot ---> it shows the numbers as well for the given rectangular grid
# #### ---> cmap ---> A specific styling theme for the heatmap itself ---> coolwarms,virdis

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
dt=gap.pivot(index='country',columns='year',values='lifeExp')

# %%
sns.heatmap(data=dt)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
dt=gap[gap['continent']=='Europe'].pivot(index='country',columns='year',values='lifeExp')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data=dt,annot=True,cmap='viridis',linewidth='0.5')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %% [markdown]
# ## ClusterMap ---> ClusterMap is combination of Both Heatmap and Automatic Grouping using Clustering
# #### It groups the similar rows and similar columns using Machine Learning Algorithm internally ---> This helps in finding the Hidden patterns in your data.
# #### Groups the students based on the marks they are scoring ---> Topper students, Average Students,....

# %%
iris=px.data.iris()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %%
## It uses Heirarchical Clustering ---> To Cluster the Rows together and it uses
## Aglomerative Heirarchical Clustering

# %% [markdown]
# ## Categorical Plots
# #### It helps to visualize the relationships where atleast one variable is Categorical and other can be either categorical or Numerical.
# #### Ctegory ---> X axis
# #### Numerical ---> Y axis
# #### Country wise sales #### Gender wise Total Bill
# #### In categorical column plots, we group the Rows based on the category of categorical column and can apply an Aggregation Operation on Numerical Columns.
# #### Categorical Column ---> Grouping the Rows
# #### Numerical Column ---> Aggregation
# #### 1. BarPlot ---> Barplot typically shows the Average value of a Numerical Column for each Category.
# #### For eg---> Average salary of Different Departments
# #### Syntax ---> sns.barplot() --->
# #### x---> categorical column
# #### y---> numerical column
# #### data ---> datafrane
# #### hue ---> optional ---> For Further split by group

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.barplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.barplot(data=gap,x='continent',y='gdpPercap')
# Out:
# <Axes: xlabel='continent', ylabel='gdpPercap'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# #### CountPlot ---> CountPlot shows the occurence of each category. As, How many number of Times a category is getting occured.
# #### For eg ---> No of Employees in each Department
# #### Syntax ---> sns.countplot()
# #### ---> x ---> Category
# #### ---> data --> dataframe

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.countplot(data=gap,x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(data=tips,x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# #### Boxplot ---> It shows the distribution of numerical variable including Median, Quartiles, Outliers for each category.
# #### As typically, we can use box plot for identifying outliers only.
# #### sns.boxplot() -->
# #### x---> category variable
# #### y---> numerical variable
# #### data ---> dataframe

# %%
sns.boxplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %% [markdown]
# #### 4. Violin Plot ----> Vilion plot is the combination of Box Plot and KDE plot and it shows the Distribution Shape and summary statistics.
# #### syntax --> sns.violinplot()
# #### ----> x ---> category variable
# #### ----> y----> numerical variable
# #### data ---> dataframe

# %%
sns.violinplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(data=gap,x='continent',y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %% [markdown]
# #### 5. Swarmplot ---> Swarmplot shows individual data points while avoiding overlapping so we can see the density and individual points
# #### sns.swarmplot()
#
# #### ---> data ---> dataframe
# #### x----> Category
# #### y ---> Numerical Variable

# %%
sales=pd.read_csv("Chocolate Sales.csv")

# %%
sales.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
sns.swarmplot(data=sales,x='Country',y='Boxes Shipped')
# Out:
# c:\Users\daksh\anaconda10\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\daksh\anaconda10\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\daksh\anaconda10\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\daksh\anaconda10\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
