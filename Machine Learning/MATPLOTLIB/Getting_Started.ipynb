# %% [markdown]
# # Getting Started with Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dating_app_behavior_dataset.csv') ## Data Gathering

# %%
df.sample(5)
# Out:
#                   gender sexual_orientation location_type income_bracket  \
# 39709        Genderfluid         Demisexual      Suburban   Upper-Middle
# 34337               Male              Queer         Metro            Low
# 38431             Female            Asexual    Small Town         Middle
# 7125              Female           Straight         Urban       Very Low
# 1616   Prefer Not to Say           Straight      Suburban   Upper-Middle
#
#       education_level                     interest_tags  app_usage_time_min  \
# 39709         Diploma       Makeup, Binge-Watching, MMA                 235
# 34337     Associate’s             Gaming, Painting, Art                  29
# 38431             MBA        Motorcycling, Makeup, Tech                 133
# 7125              PhD           Startups, DIY, Painting                 185
# 1616          Postdoc  Astrology, Crafting, Board Games                 274
#
#       app_usage_time_label  swipe_right_ratio swipe_right_label  \
# ...

# %%
df.shape
# Out:
# (50000, 19)

# %%
# Data Exploration while plotting graphs --> Dataset --> Which Categorical column or numerical column

# %% [markdown]
# ## Categorical Column
#
# #### 10 Students --> 10 Mobile phone of Different Brands ---> Different Brands ---> Category
# #### 1. Apple
# #### 2. Nokia
# #### 3. Samsung
#
# ## Numerical Columns
# #### 100 Students Age --->> 12,15,23,53,63.....
# #### 100 Batsman Score ---> 323,4324,534...

# %%
df.columns
# Out:
# Index(['gender', 'sexual_orientation', 'location_type', 'income_bracket',
#        'education_level', 'interest_tags', 'app_usage_time_min',
#        'app_usage_time_label', 'swipe_right_ratio', 'swipe_right_label',
#        'likes_received', 'mutual_matches', 'profile_pics_count', 'bio_length',
#        'message_sent_count', 'emoji_usage_rate', 'last_active_hour',
#        'swipe_time_of_day', 'match_outcome'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis & Bivariate Analysis
#
# #### Univariate--> Analysis or will be creating visualization for a given unique column --> How values are spread in my Age Column
# #### Age ---> 23 ----> 40
# #### 17--->10
# #### 59---> 1
#
# #### Bivatiate---> Analysis of 2 Columns ---> Column_1 ---> Date --> Month
# #### Column_2 ---> Sale in a Month
#
# #### Plot a Chart ---> Month on Month Sales of products for a company
# #### Bivariate Analysis -->
# #### 1. Numeric-Numeric
# #### 2. Numeric-Categorical
# #### 3. Categorical-Categorical
#
# #### Multivariate Analysis --> Work with Multiple Columns ---> more than 2 columns

# %% [markdown]
# ## 2D Line Plot
# #### Specific Purpose --> Specific Plot
#
# #### 2D Line Plot --> usually work with 2 columns ---> Categorical-Numerical
# #### X-axis ---> Categorical column Data or Category
# #### Y-axis ---> Value that is going to change or that varies for the category
#
# #### 2D Line Plot or in general line plot, it can be used for time series data
# #### Time Series Data --> stock price on month on month basis
# #### Time series data is the data that varies with time or it can be the data where the values varies continuously (Phone Brand --> Price)
# #### Tracking Weight over the months (time series data)

# %% [markdown]
# ### Dataset ---> Indian Actors fees for a movie
# #### Actors name ---> Categorical ---> X-axis
# #### Price ---> Numerical ---> Y-axis

# %%
x=['Sharukh Khan','Salman Khan','Amir Khan','Sanjay Dutt','Saif Ali Khan']
y=[7000000,8000000,5000000,400000,10000000]

## Create a line plot ---> plt.plot(x,y) --> plot()--> create the graph for us
plt.plot(x,y)

# %%
df.head()
# Out:
#               gender sexual_orientation location_type income_bracket  \
# 0  Prefer Not to Say                Gay         Urban           High
# 1               Male           Bisexual      Suburban   Upper-Middle
# 2         Non-binary          Pansexual      Suburban            Low
# 3        Genderfluid                Gay         Metro       Very Low
# 4               Male           Bisexual         Urban         Middle
#
#        education_level                  interest_tags  app_usage_time_min  \
# 0           Bachelor’s   Fitness, Politics, Traveling                  52
# 1  No Formal Education  Languages, Fashion, Parenting                 279
# 2             Master’s           Movies, Reading, DIY                  49
# 3              Postdoc      Coding, Podcasts, History                 185
# 4           Bachelor’s       Clubbing, Podcasts, Cars                  83
#
#   app_usage_time_label  swipe_right_ratio swipe_right_label  likes_received  \
# ...

# %%
df['gender'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='gender'>

# %%
data=df['gender'].value_counts()

# %%
x=data.index
y=data.values

# %%
plt.plot(x,y)

# %% [markdown]
# #### plt.figure()---> figure()---> parameter--> figsize--->(len,breadth)---> figure dimension of our graph
# #### plt.figure*figsize=(10,6)
#
# #### plt.title() ---> title() --> It takes the value as the Title of your plot that what it is representing as what insight we are getting through this graph,
# ####  parameter ---> color ---> what color the Title is going to have
# #### plt.ylabel()--> helps represent that y axis is repersenting to us
# #### plt.xlabel()---> helps represent that x axis is representing to us
# #### plt.grid()---> helps to bring grid on our visualization
# #### plt.show()---> helps in representing the chart
# #### plt.xlim()---> X values ---> [10,1000] ---> [100,1000]---> [700,800] ---> It puts a limitation that how much the data must be represented on the x Axis
# #### plt.ylim()---> Y values --->[500,900]--->[600,700]--> It puts the limitation that how much values will be shown on the y-axis

# %%
plt.figure(figsize=(10,6))
plt.title('Count of Population as per Gender',color='red')
plt.ylabel('Count of Population')
plt.xlabel('Gender')
plt.plot(x,y,color='red',marker='o', linestyle='--', linewidth=1.5,markersize=9,label='Gender Population')
plt.grid()
plt.show()

# %% [markdown]
# ## Customization For Line
# #### Parameters:
# #### 1. color  ---> What is going to be the color of the line --> for eg: red,greeen, blue, or HTML hash code
#
# #### 2. marker ---> how point of intersection appears --> o, s, +, *, d
# #### 3. linestyle ---> it will be defining the style  of the line ---> '--','-.'
# #### 4. linewidth ---> it shows the width of the line ---> 1,1.5,2
# #### 5. markersize---> it shows the markersize or it can change the size of the marker, default-->6, --> 10,9,12
# #### 6. label --> label that what this specific line is representing but is only helpful while plotting multiple lines in a single visualization

# %%
df.sample(5)
# Out:
#                   gender sexual_orientation location_type income_bracket  \
# 22360  Prefer Not to Say          Pansexual         Metro           High
# 36020        Genderfluid          Pansexual         Metro      Very High
# 32203             Female                Gay    Small Town      Very High
# 7017                Male                Gay      Suburban   Upper-Middle
# 30190        Genderfluid            Lesbian    Small Town      Very High
#
#       education_level                   interest_tags  app_usage_time_min  \
# 22360      Bachelor’s           Coding, Movies, Memes                  98
# 36020     Associate’s       Crafting, Fitness, Hiking                 118
# 32203         Diploma  Spirituality, Movies, Politics                 189
# 7017      High School        Meditation, Running, Art                  74
# 30190         Diploma    Photography, Fitness, Foodie                 250
#
#       app_usage_time_label  swipe_right_ratio swipe_right_label  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gender                50000 non-null  object
#  1   sexual_orientation    50000 non-null  object
#  2   location_type         50000 non-null  object
#  3   income_bracket        50000 non-null  object
#  4   education_level       50000 non-null  object
#  5   interest_tags         50000 non-null  object
#  6   app_usage_time_min    50000 non-null  int64
#  7   app_usage_time_label  50000 non-null  object
#  8   swipe_right_ratio     50000 non-null  float64
#  9   swipe_right_label     50000 non-null  object
#  10  likes_received        50000 non-null  int64
#  11  mutual_matches        50000 non-null  int64
#  12  profile_pics_count    50000 non-null  int64
#  13  bio_length            50000 non-null  int64
#  14  message_sent_count    50000 non-null  int64
# ...

# %%
sales=pd.read_csv("Chocolate Sales.csv")

# %%
sales.head(5)
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
sales.shape
# Out:
# (1094, 6)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   object
#  1   Country        1094 non-null   object
#  2   Product        1094 non-null   object
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   object
#  5   Boxes Shipped  1094 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 51.4+ KB

# %%
sales['Sales Person']=sales['Sales Person'].astype('category')

# %%
sales['Country']=sales['Country'].astype('category')

# %%
sales['Product']=sales['Product'].astype('category')

# %%
sales['Date']=pd.to_datetime(sales['Date'])
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\4046355403.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Date']=pd.to_datetime(sales['Date'])

# %%
sales['Date']=sales['Date'].dt.month_name()

# %%
sales['Date']
# Out:
# 0        January
# 1         August
# 2           July
# 3          April
# 4       February
#           ...
# 1089         May
# 1090        June
# 1091        July
# 1092        July
# 1093         May
# Name: Date, Length: 1094, dtype: object

# %% [markdown]
# ### To convert a Date column to datetime you can use pd.to_datetime()
# ### To extract the year from the datetime column ---> df['col_name'].dt.year
# ### To extract the Month value(1-12) from the DateTime column ---> df['col_name'].dt.month
# ### To extract the Month name from the DateTime Column ---> df['col_name'].dt.month_name()

# %%
sales['Amount'].value_counts()
# Out:
# Amount
# $2,317      5
# $2,303      4
# $7,714      4
# $4,361      4
# $6,454      4
#            ..
# $16,233     1
# $5,313      1
# $3,528      1
# $2,450      1
# $4,410      1
# Name: count, Length: 827, dtype: int64

# %%
sales['Amount']=sales['Amount'].str.strip("$")

# %%
sales['Amount']
# Out:
# 0        5,320
# 1        7,896
# 2        4,501
# 3       12,726
# 4       13,685
#          ...
# 1089     4,410
# 1090     6,559
# 1091       574
# 1092     2,086
# 1093     5,075
# Name: Amount, Length: 1094, dtype: object

# %%
sales['Amount']=sales['Amount'].str.replace(",","")

# %%
sales['Amount']
# Out:
# 0        5320
# 1        7896
# 2        4501
# 3       12726
# 4       13685
#          ...
# 1089     4410
# 1090     6559
# 1091      574
# 1092     2086
# 1093     5075
# Name: Amount, Length: 1094, dtype: object

# %%
sales['Amount']=sales['Amount'].astype('int32')

# %%
sales['Boxes Shipped']=sales['Boxes Shipped'].astype('int32')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   category
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   category
#  3   Date           1094 non-null   object
#  4   Amount         1094 non-null   int32
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(3), int32(2), object(1)
# memory usage: 22.1+ KB

# %%
sales['Date']=sales['Date'].astype('category')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   1094 non-null   category
#  1   Country        1094 non-null   category
#  2   Product        1094 non-null   category
#  3   Date           1094 non-null   category
#  4   Amount         1094 non-null   int32
#  5   Boxes Shipped  1094 non-null   int32
# dtypes: category(4), int32(2)
# memory usage: 15.0 KB

# %%
data=sales.groupby('Date')['Amount'].sum()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\459929276.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data=sales.groupby('Date')['Amount'].sum()

# %%
data
# Out:
# Date
# April       674051
# August      743148
# February    699377
# January     896105
# July        803425
# June        865144
# March       749483
# May         752892
# Name: Amount, dtype: int32

# %%
data.index=pd.CategoricalIndex(data.index,categories=['January','February','March','April','May','June','July','August'])

# %%
data=data.sort_index()

# %%
x=data.index

# %%
y=data.values

# %%
plt.figure(figsize=(10,6))
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.plot(x,y,linewidth=1.5,linestyle='--',color='red',marker='o')
plt.grid()
plt.show()

# %% [markdown]
# ## Types of Plots
# #### 1. Line Plot ---> Time Series Analysis ---> How values are varying as per Time
# #### 2. Scatter Plot --> Scatter Plot is being used for Bivariate Analysis ---> Two Numerical Columns --> We check that based on the changes in one Numerical Column Value ---> How it affects the other Numerical Column Value
# #### for example --->  x ---> Age  ---> 10,15,20,25,30...
# ####  y --> Cholestrol Level ---> 50,60,75,80,....
#
# #### Scatter Plot ---> It will figure out that based on the increment in Age Value --> If cholestrol level is Increasing or Decreasing or Is Steady
# #### Scatter Plot ---> it figures out the correlation between the two numerical values

# %%
x=np.linspace(-10,10,50)
y=10+x+3 + np.random.randint(0,300,50)
plt.scatter(x,y)

# %%
sales.sample(5)
# Out:
#         Sales Person Country              Product      Date  Amount  \
# 812     Barr Faughny  Canada  Organic Choco Syrup     March    1141
# 167  Roddy Speechley   India  Peanut Butter Cubes  February   10283
# 847   Dotty Strutley  Canada          After Nines   January     252
# 567   Jehu Rudeforth      UK  Baker's Choco Chips       May    2485
# 465   Andria Kimpton     USA  Spicy Special Slims       May    2366
#
#      Boxes Shipped
# 812            205
# 167             21
# 847            237
# 567             97
# 465              5

# %%
x=sales['Boxes Shipped']
y=sales['Amount']

# %%
plt.figure(figsize=(10,4))
plt.title('Total Amount Variation as per Total Boxes Shipped')
plt.xlabel('Number of Boxes')
plt.ylabel('Amount')
plt.scatter(x,y,color='red',marker='o')
plt.show()

# %% [markdown]
# #### If there is any way in which we can create a scatter plot from line plot only
# #### Line Plot ---> Special case of scatter plot as soon as we will join the points of scatter plot we will get the line plot
# ### Large Dataset --> Lakhs or Crores of Rows --> plot('o') --> Scatter Plot --> Faster
# ### Small Dataset ---> Hundreds or Thousand of Rows ---> scatter() --> Scatter Plot ---> Faster

# %% [markdown]
# #### Line Chart --> Line Chart was being used for representing Time Series Analysis
# #### Scatter Plot --> Scatter Plot is used to represent the corelation in between Two Numerical Columns (Such that how on changes in the first numerical column it affects the variation in the second numerical Column)
# #### Bar Plot --> Bar Plot is being used for Categorical --> Numerical Columns
# #### Data ---> Sales in Multiple Countries --> group the rows on the basis of Country Name & will come up with the Total Sum of Sales
# #### 1000 records ---> 80 records--> India ---> group all 80 rows or records --->Sales value associated with these 80 rows ---> Aggeration Operation (sum(), count(), mean())
#
# #### Categorial Column ---> Numerical Column Aggregation
# #### groupby --> is something we will using Everytime
# #### Univariate ----> Categorical Column Data Distribution (how the data in Multiple Categories is Distributed)
# #### Use case ---> Aggregate Analysis of Groups

# %%
# remove_unused_categories()
# concat() ---> concat() function joins two dataset or Multiple dataset by using concat()
## pd.concat([df_1,df_2,df_3,......])

# %%
sales
# Out:
#           Sales Person    Country              Product      Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco   January    5320
# 1          Van Tuxwell      India        85% Dark Bars    August    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes      July    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes     April   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  February   13685
# ...                ...        ...                  ...       ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims       May    4410
# 1090    Jehu Rudeforth        USA           White Choc      June    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup      July     574
# 1092    Dotty Strutley      India              Eclairs      July    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites       May    5075
#
#       Boxes Shipped
# 0               180
# 1                94
# 2                91
# ...

# %%
# Country Based Total Sales

# %%
data=sales.groupby('Country')['Amount'].sum()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\2957121949.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data=sales.groupby('Country')['Amount'].sum()

# %%
data
# Out:
# Country
# Australia      1137367
# Canada          962899
# India          1045800
# New Zealand     950418
# UK             1051792
# USA            1035349
# Name: Amount, dtype: int32

# %%
x=data.index
y=data.values

# %%
plt.figure(figsize=(7,4))
plt.title('Country Based Total Sales')
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.bar(x,y,color='green',width=0.4)
plt.show()

# %%
sales['Product'].value_counts().head(7)
# Out:
# Product
# 50% Dark Bites         60
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Spicy Special Slims    54
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
data=sales[(sales[('Product')]=='50% Dark Bites') | (sales['Product']=='Eclairs') | (sales['Product'] == 'Smooth Sliky Salty') | (sales['Product'] =='White Choc') | (sales['Product']=='Drinking Coco') | (sales['Product'] == 'Spicy Special Slims') | (sales['Product'] == 'Organic Choco Syrup')]

# %%
data['Product'].value_counts()
# Out:
# Product
# 50% Dark Bites          60
# Eclairs                 60
# Smooth Sliky Salty      59
# White Choc              58
# Drinking Coco           56
# Spicy Special Slims     54
# Organic Choco Syrup     52
# After Nines              0
# Mint Chip Choco          0
# 85% Dark Bars            0
# Raspberry Choco          0
# Peanut Butter Cubes      0
# Orange Choco             0
# Milk Bars                0
# Almond Choco             0
# Manuka Honey Choco       0
# 70% Dark Bites           0
# 99% Dark & Pure          0
# Choco Coated Almonds     0
# Caramel Stuffed Bars     0
# Baker's Choco Chips      0
# Fruit & Nut Bars         0
# Name: count, dtype: int64

# %%
data['Product']=data['Product'].cat.remove_unused_categories()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\3291096538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Product']=data['Product'].cat.remove_unused_categories()

# %%
data['Product'].value_counts()
# Out:
# Product
# 50% Dark Bites         60
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Spicy Special Slims    54
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
d=data.groupby('Product')['Boxes Shipped'].sum()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\1069043398.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d=data.groupby('Product')['Boxes Shipped'].sum()

# %%
x=d.index
y=d.values

# %%
plt.figure(figsize=(7,4))
plt.title('Producr Based Total Boxes Shipped')
plt.xlabel('Product')
plt.ylabel('Total Boxes')
plt.bar(x,y,color='green',width=0.4)
plt.show()

# %%
## xticks() --> Remove the Label Overlapping Issue
# xticks()---> parameter --> rotation='vertical' ---> xticks(rotation='vertical')

# %%
plt.figure(figsize=(7,4))
plt.title('Producr Based Total Boxes Shipped')
plt.xlabel('Product')
plt.ylabel('Total Boxes')
plt.bar(x,y,color='green',width=0.4)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Horizontal Bar Chart ---> Bars are going to be Horizontal
# ## barh()--> Horizontal Bar Chart

# %%
sales.head()
# Out:
#      Sales Person    Country              Product      Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco   January    5320
# 1     Van Tuxwell      India        85% Dark Bars    August    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes      July    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes     April   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  February   13685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
plt.figure(figsize=(7,4))
plt.title('Producr Based Total Boxes Shipped')
plt.xlabel('Total Boxes Shipped')
plt.ylabel('Product')
plt.barh(x,y,color='green')
plt.show()

# %%
# Multiple Bar Charts
### dataset--> Product Sales over the Months
### Mobiles--> Sales on Month on Month Basis
### AC--> Sales on Month on Month Basis
### Television--> Sales on Month on Month Basis

# %%
m=sales[sales['Product']=='Mint Chip Choco']
d=sales[sales['Product']=='85% Dark Bars']
p=sales[sales['Product']=='Peanut Butter Cubes']

# %%
m=m.groupby('Date')['Amount'].sum()
d=d.groupby('Date')['Amount'].sum()
p=p.groupby('Date')['Amount'].sum()
# Out:
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\1458143030.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   m=m.groupby('Date')['Amount'].sum()
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\1458143030.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d=d.groupby('Date')['Amount'].sum()
# C:\Users\daksh\AppData\Local\Temp\ipykernel_24736\1458143030.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
m
# Out:
# Date
# April       13160
# August      32718
# February    63518
# January     49525
# July        27783
# June        34293
# March       33467
# May         29505
# Name: Amount, dtype: int32

# %%
plt.bar(m.index,m.values)
# Out:
# <BarContainer object of 8 artists>

# %%
m.index=pd.CategoricalIndex(m.index,categories=['January','February','March','April','May','June','July','August'],ordered=True)

# %%
d.index=pd.CategoricalIndex(d.index,categories=['January','February','March','April','May','June','July','August'],ordered=True)

# %%
p.index=pd.CategoricalIndex(p.index,categories=['January','February','March','April','May','June','July','August'],ordered=True)

# %%
m=m.sort_index()
d = d.sort_index()
p = p.sort_index()

# %%
plt.figure(figsize=(7,4))
plt.xlabel('Month Name')
plt.ylabel('Total Sales')
plt.bar(m.index,m.values,color='green',label='Mint Chip Choco')
plt.legend()
plt.show()

# %%
x=['January','February','March','April','May','June','July','August']

# %%
plt.figure(figsize=(7,4))
plt.xlabel('Month Name')
plt.ylabel('Total Sales')
plt.bar(np.arange(m.shape[0]) -0.2,m.values,color='green',label='Mint Chip Choco',width=0.2)
plt.bar(np.arange(d.shape[0]),d.values,color='blue',label='85% Dark Bars',width=0.2)
plt.bar(np.arange(p.shape[0])+0.2,p.values,color='red',label='Peanut Butter Cubes',width=0.2)
plt.xticks(np.arange(m.shape[0]) -0.2,x)
plt.legend()
plt.show()

# %%
# Equal Spacing for your multiple bars --> We can show the Red Bar at first , then gren then blue just building side by side

# %% [markdown]
# ## xticks ---> This specific function can help us out with Replacing the Original Label with the New Label --> xticks(original_label,new_label)

# %% [markdown]
# ## Stacked Bar Chart
#
# #### Instead of keeping the Bars in Side by side direction, we can keep the bars in the Stacked Manner i.e, One on Top of Other and in order to Figure out which category is having maximum sale, we can have a look over the length of the Bar
#
# ## Stacked Bar Chart ---> bar() --> parameter ---> bottom ---> This bottom parameter sepcific that what bar i want to keep below my current bar
#
# #### Red Bar
# #### Green Bar ---> bottom ---> Red Bar
# #### Blue Bar ---> bottom---> Green Bar + Red Bar
#
# #### As we want to differentiate on the basis of Bar Length Value so that's why we have to keep y_value of previous bar at the  bottom

# %%
plt.figure(figsize=(7,4))
plt.xlabel('Month Name')
plt.ylabel('Total Sales')
plt.bar(m.index,m.values,color='green',label='Mint Chip Choco')
plt.bar(d.index,d.values,color='blue',label='85% Dark Bars',bottom=m.values)
plt.bar(p.index,p.values,color='red',label='Peanut Butter Cubes',bottom=(m.values+d.values))
plt.legend()
plt.show()
